# %%
import pandas as pd
import numpy as np 
from sklearn.linear_model import LinearRegression
import math

# %% [markdown]
# ## predict using sklearn

# %%
df = pd.read_csv('test_scores.csv')
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
model = LinearRegression()

# %%
model.fit(df[['math']], df['cs'])
# Out:
# LinearRegression()

# %%
# coefficient = m
model.coef_
# Out:
# array([1.01773624])

# %%
# intercept = b
model.intercept_
# Out:
# np.float64(1.9152193111568891)

# %% [markdown]
# ##### this coeficient(m) and intercept(b) is to be compared with m and b found through gradient descent algorithm

# %% [markdown]
# ## predict using gradient descent algorithm

# %%
def gradient_descent(x,y):
    m_curr = 0
    b_curr = 0
    iterations = 1000000
    n = len(x)
    learning_rate = 0.0002

    cost_previous = 0
    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n)*sum((y-y_predicted)**2)
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        if math.isclose(cost, cost_previous, rel_tol=1e-20):
            break
        cost_previous = cost
        if i % 100 == 0:
            print(f"cost = {cost}, m = {m_curr}, b = {b_curr}") 
    return m_curr, b_curr

# %%
    x = np.array(df.math)
    y = np.array(df.cs)

# %%
m, b = gradient_descent(x,y)
print(f" m = {m} , b = {b}")
# Out:
# cost = 5199.1, m = 1.9783600000000003, b = 0.027960000000000002
# cost = 31.810902767107496, m = 1.0445042032954506, b = 0.01914139384070658
# cost = 31.809956321331267, m = 1.0444301754614103, b = 0.023489255496841506
# cost = 31.809015158729483, m = 1.044368961396937, b = 0.02782732515951949
# cost = 31.80807830768114, m = 1.0443078878786798, b = 0.03215544686806328
# cost = 31.807145748434607, m = 1.0442469544127415, b = 0.03647364343245952
# cost = 31.80621746132874, m = 1.044186160677955, b = 0.040781937612809044
# cost = 31.80529342679248, m = 1.0441255063538926, b = 0.04508035211701967
# cost = 31.804373625344386, m = 1.0440649911208613, b = 0.04936890960092604
# cost = 31.803458037592282, m = 1.0440046146599007, b = 0.053647632668409106
# cost = 31.802546644232844, m = 1.0439443766527818, b = 0.05791654387151493
# cost = 31.801639426051175, m = 1.0438842767820056, b = 0.0621756657105739
# cost = 31.800736363920404, m = 1.0438243147308004, b = 0.06642502063431925
# ...

# %% [markdown]
# ### after comparision we saw that both values are equal
